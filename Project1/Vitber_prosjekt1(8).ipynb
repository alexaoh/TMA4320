# %% [markdown]
# # Exercise 3.1:
# We will show that equation (6) in the task description is a solution of the diffusion equation by simply inserting it into the equation with constant diffusion coefficient, since the coefficient $D$ is independent of x in the solution.
#
# To show that
#
# $\phi(x,t) = \frac{1}{\sqrt{4\pi Dt}} \int^{+\infty}_{-\infty}dy\,h(y)e^{-\frac{(x-y)^2}{4Dt}}$
#
# is a solution of
#
# $\frac{\partial \phi(x, t)}{\partial t} = D\frac{\partial^2\phi(x,t)}{\partial^2x}$,
#
# we first calculate
#
# $\frac{\partial \phi(x, t)}{\partial t} = -\frac{1}{2} \frac{1}{\sqrt{4\pi Dt}} \frac{1}{t} \int^{+\infty}_{-\infty}dy\,h(y)e^{-\frac{(x-y)^2}{4Dt}} + \frac{1}{\sqrt{4\pi Dt}} \frac{1}{t^2}\int^{+\infty}_{-\infty}dy\,h(y) \, \frac{(x-y)^2}{4D}e^{-\frac{(x-y)^2}{4Dt}} = \frac{1}{\sqrt{4\pi Dt}}(\frac{1}{t^{2}} \int^{+\infty}_{-\infty}dy\,h(y)\,\frac{(x-y)^2}{4D}e^{-\frac{(x-y)^2}{4Dt}} - \frac{1}{2t} \int^{+\infty}_{-\infty}dy\,h(y)e^{-\frac{(x-y)^2}{4Dt}})$.
#
# Then we find
#
# $\frac{\partial\phi(x,t)}{\partial x} = \frac{1}{\sqrt{4\pi Dt}} (-\frac{1}{4Dt}) \int^{+\infty}_{-\infty}dy\,h(y)\,(2x-2y)e^{-\frac{(x-y)^2}{4Dt}}$
#
# $\implies \frac{\partial^2 \phi(x,t)}{\partial^2 x} = \frac{1}{\sqrt{4\pi Dt}}\frac{1}{4Dt}(-\int^{+\infty}_{-\infty}dy\,h(y)\,2e^{-\frac{(x-y)^2}{4Dt}} + \int^{+\infty}_{-\infty}dy\,h(y)\,\frac{(2x-2y)^2}{4Dt}e^{-\frac{(x-y)^2}{4Dt}}) = \frac{1}{D\sqrt{4\pi Dt}}(\frac{1}{t^{2}} \int^{+\infty}_{-\infty}dy\,h(y)\,\frac{(x-y)^2}{4D}e^{-\frac{(x-y)^2}{4Dt}} - \frac{1}{2t} \int^{+\infty}_{-\infty}dy\,h(y)e^{-\frac{(x-y)^2}{4Dt}})$.
#
# It is apparent that the expression (6) is a solution of the equation:
#
# $\implies \frac{\partial \phi(x, t)}{\partial t} = D\frac{\partial^2\phi(x,t)}{\partial^2x}$ $$\tag*{$\blacksquare$}$$
#
#
# This soulution (6) of the diffusion equation can also be found by applying a Fourier transform to the diffusion equation. By finding the solution this way, it becomes apparent from the beginning of the calculations that h(x) represents the initial distribution of the particles, before the diffusion begins. This means that h(y) gives the contribution of each point in y-space (the space the Fourier transform transforms the distribution h(x) into) to the diffusion process or, in other words, gives the position of each particle during the diffusion process.

# %% [markdown]
# # Exercise 3.2:
# The probability of finding a particle in position $x$ in a potential landscape $V(x)$ is given by $P(x) = Ze^{-\beta V(x)}$, where $Z$ is the canonical partition function of the system and $\beta = (k_B T)^{-1}$.
#
# During a random walk the probability of a particle moving in the positive direction, staying put or moving in the negative direction is, respectively, $\{p^{+}, p^{0}, p^{-}\}$. Normalization dictates that their combined sum should equal one. This means the probabilities must satisfy the equation
#
# \begin{equation}\label{eq1}\tag{1}
# p^{+} + p^{0} + p^{-} = 1.
# \end{equation}
#
# We assume that each of the probabilities are proportional to $P(x)$ and that the proportionality constant, $C$, is equal for all steps. If the position before a random walk step is $x_0$ we get
#
# \begin{equation}
#   \begin{aligned}
#     p^{+} & =CP(x_0+1),\\
#     p^{0} & =CP(x_0),\\
#     p^{-} & =CP(x_0-1).
#     \label{eq2}
#   \end{aligned}
# \end{equation}
#
# By putting these expressions into equation \eqref{eq1} we find the constant
#
# \begin{equation}\label{eq3}
# C=\frac{1}{P(x_0+1)+P(x_0)+P(x_0-1)},
# \end{equation}
#
# and the desired probabilities
#
# \begin{equation}
#   \begin{aligned}
#     p^{+} &=\frac{P(x_0+1)}{P(x_0+1)+P(x_0)+P(x_0-1)} = \frac{1}{1+e^{-\beta [V(x_0-1)-V(x_0+1)]}+e^{-\beta [V(x_0)-V(x_0+1)]}}, \\
#     p^{0} &=\frac{P(x_0)}{P(x_0+1)+P(x_0)+P(x_0-1)} = \frac{1}{1+e^{-\beta [V(x_0-1)-V(x_0)]}+e^{-\beta [V(x_0+1)-V(x_0)]}}, \\
#     p^{-} &=\frac{P(x_0-1)}{P(x_0+1)+P(x_0)+P(x_0-1)} = \frac{1}{1+e^{-\beta [V(x_0+1)-V(x_0-1)]}+e^{-\beta [V(x_0)-V(x_0-1)]}}.
#     \label{eq4}
#   \end{aligned}
# \end{equation}
# $$\tag*{$\blacksquare$}$$

# %% [markdown]
# # Exercise 3.3:
# With the contidion
#
# $k_B T  \gg  \left|V(x+1)-V(x) \right| = \left|\Delta V(x)\right|  \implies  \beta \left|\Delta V(x) \right| \ll 1,$
#
# all the exponential terms will go towards one;  $e^{-\beta \left|\Delta V(x) \right|} \approx e^{\beta \left| \Delta V(x) \right|} \approx 1$. Since the contidion must hold for any $x$ the difference in potential, $\left| \Delta V(x) \right|$, represents a difference for an arbitrary position $x$. By inserting $\left| \Delta V(x) \right|$ in the probabilities found in task 3.2 and taking absolute value we get
#
# \begin{equation}\label{eq5}\tag{2}
# p^{+} = \frac{1}{1+e^{2 \beta \left| \Delta V(x) \right|} + e^{\beta \left| \Delta V(x) \right|}} \approx \frac{1}{3},
# \end{equation}
#
# \begin{equation}\label{eq6}\tag{3}
# p^{0} = \frac{1}{1+e^{\beta \left| \Delta V(x) \right|} + e^{-\beta \left| \Delta V(x) \right|}} \approx \frac{1}{3},
# \end{equation}
#
# \begin{equation}\label{eq7}\tag{4}
# p^{-} = \frac{1}{1+e^{-2 \beta \left| \Delta V(x) \right|} + e^{-\beta \left| \Delta V(x) \right|}} \approx \frac{1}{3}.
# \end{equation}
#
# This makes sense cause here the potential is insignificant in relation to the thermal energy and therefore the particles must have equal probabilities to either stay put, move to left or to the right.
#
# To check the other option, when the potential difference is much bigger than the thermal energy
# $k_B T  \ll  \left|V(x+1)-V(x) \right| = \left|\Delta V(x)\right|$. From this we obatin
# $\beta \left|\Delta V(x) \right| \gg 1 \implies e^{\beta \left| \Delta V(x) \right|} \approx \infty,$ and for the negative case
# $ -\beta \left|\Delta V(x) \right| \ll 1 \implies e^{-\beta \left| \Delta V(x) \right|} \approx 0$.
#
# With the same expressions for the probabilities as in equation \eqref{eq5}, \eqref{eq6} and \eqref{eq7} we wee that $p^{+} \approx p^{0} \approx 0$ and
#
# \begin{equation}
# p^{-} = \frac{1}{1+e^{-2 \beta \left| \Delta V(x) \right|} + e^{-\beta \left| \Delta V(x) \right|}} \approx 1.
# \end{equation}
#
# If the potential difference was set the other way in the condition $k_B T  \ll  \left|V(x)-V(x+1) \right|$ the probability $p^{+}$ would go towards one and $p^{0} \approx p^{-} \approx 0$.
#
# This shows that in the first case the potential is negligible, and in the second the thermal energy is neglible.
# **How can we simplify the random walk problem using an energy scale argument in the two limits given above?**

# %% [markdown]
# # Programming exercise 4:

# %%
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt 
from math import e
import random as rand
from numba import jit

@jit(nopython=True)
def p_plus(x_0, V, beta_k):
    '''
    Probability of random walk step to the right.
    '''
    return 1/(1+e**(-beta_k*(V(x_0-1)-V(x_0+1)))+e**(-beta_k*(V(x_0)-V(x_0+1))))

@jit(nopython=True)
def p_zero(x_0, V, beta_k):
    '''
    Probability of staying put during random walk simulation.
    '''
    return 1/(1+e**(-beta_k*(V(x_0-1)-V(x_0)))+e**(-beta_k*(V(x_0+1)-V(x_0))))

@jit(nopython=True)
def p_minus(x_0, V, beta_k):
    '''
    Probability of random walk step to the left.
    '''
    return 1/(1+e**(-beta_k*(V(x_0+1)-V(x_0-1)))+e**(-beta_k*(V(x_0)-V(x_0-1))))

#Constants used in exercise 4
time_steps = 200
amount_of_particles = 100
beta_k = [0.01, 1, 100] 
step_length = 1
initial = np.zeros((amount_of_particles,), dtype=np.int64)

@jit(nopython=True)
def get_result(V, betaAndK, init):
    new_array = init.copy()
    for step in range(time_steps):
        for position in range(len(init)):
            p = np.random.uniform(0,1)
            if p <= p_minus(new_array[position],V, betaAndK):
                new_array[position] -= step_length
            elif p > (1-p_plus(new_array[position],V, betaAndK)):
                new_array[position] += step_length
    return new_array

''' Dette kan fjernes (mest sannsynlig) før innlevering
#Plotting result
def plot_result(result):
    y = np.zeros(((max(result)-min(result))+1,),dtype=np.int64)
    for element in result:
        indeks = int(element-min(result))
        y[indeks] += 1   
    x = np.arange(min(result), max(result)+1, 1)
    plt.plot(x,y, label="Raw data")
    print(x,y)
    #Får ikke til scipy.fit!
    #mean, std = norm.fit(y)
    #pdf = norm.pdf(y, mean, std)
    #plt.plot(x, pdf, label="PDF")
    plt.legend()
    plt.show()

    #fig, axs = plt.subplots(1, 3, figsize=(10, 4), tight_layout=True)
    #axs[0].plot(x,y) #example on how to plot subplots, but need to do some changes to be able to plot all three of them
    #axs[1].plot(x,y) #Maybe hard to do in one general function like this
    #axs[2].plot(x,y)
    #plt.plot(x,y)
    #####plt.plot(x, norm.pdf(y)) #use norm to fit somehow
    #plt.show()
'''

@jit(nopython=True) 
def mean(data):
    '''
    Finds the mean of data. 
    '''
    sum = 0
    for element in data:
        sum += element
    return sum/len(data)

@jit(nopython=True)
def std(data):
    '''
    Finds the standard deviation of data. 
    '''
    sum = 0
    mu = mean(data)
    n = len(data)
    for element in data:
        sum += (element-mu)**2
    return np.sqrt(sum/(n-1))

@jit(nopython=True)
def normal(x,mean,std):
    '''
    Finds the normal distribution. 
    '''
    return 1/(std*np.sqrt(2*np.pi)) * np.e**(-1/2 * ((x-mean)/std)**2)


def plot_hist(result1, result2, result3):  
    '''
    Histogram plot.
    '''
    x1 = np.arange(min(result1),max(result1),1)
    x2 = np.arange(min(result2),max(result2),1)
    x3 = np.arange(min(result3),max(result3),1)
    x_values = [x1, x2, x3]
    xaxe = "Particle position"
    yaxe = "Intensity"
    titles = [r'$\beta k = 0.01$',r'$\beta k = 1$',r'$\beta k = 100$'] 
    data = [result1, result2, result3]
    f,a = plt.subplots(1,3, figsize=(21,8))
    a[0].set_ylabel(yaxe, fontsize=20)
    a = a.ravel()
    for idx,ax in enumerate(a):
        ax.hist(data[idx])
        ax.set_title(titles[idx], fontsize=20)
        ax.set_xlabel(xaxe, fontsize=20)
        ax.text(0.5,-0.2, "Mean: " + str(mean(data[idx])) + ", Std: " + str(round(std(data[idx]),3)) , size=15, ha="center",transform=ax.transAxes)
        if (std(data[idx]) != 0):
            ax.plot(x_values[idx], normal(x_values[idx], mean(data[idx]), std(data[idx])))
    plt.tight_layout(pad = 2.0)
    plt.show()

def plot_normhist(result1, result2, result3): 
    '''
    Plots normalized histogram plot. 
    '''
    x1 = np.arange(min(result1),max(result1),1)
    x2 = np.arange(min(result2),max(result2),1)
    x3 = np.arange(min(result3),max(result3),1)
    x_values = [x1, x2, x3]
    xaxe = "Particle position"
    yaxe = "PDF"
    titles = [r'$\beta k = 0.01$',r'$\beta k = 1$',r'$\beta k = 100$'] 
    data = [result1, result2, result3]
    f,a = plt.subplots(1,3, figsize=(21,8))
    #a = a.ravel()
    a[0].set_ylabel(yaxe, fontsize=20)
    for idx,ax in enumerate(a):
        ax.hist(data[idx], density = True, label="PDF")
        ax.set_title(titles[idx], fontsize=20)
        ax.set_xlabel(xaxe, fontsize=20)
        ax.text(0.5,-0.2, "Mean: " + str(mean(data[idx])) + ", Std: " + str(round(std(data[idx]),3)) , size=15, ha="center", 
         transform=ax.transAxes)
        if (std(data[idx]) != 0):
            ax.plot(x_values[idx], normal(x_values[idx], mean(data[idx]), std(data[idx])))
        
    plt.tight_layout(pad = 2.0)
    plt.show()

# %% [markdown]
# ## Programming exercise 4.1:

# %%
@jit(nopython=True)
def V_1(x):
    '''
    Potential in exercise 4.1
    '''
    k = 1
    return k

result1 = get_result(V_1,beta_k[0], initial)
result2 = get_result(V_1,beta_k[1], initial)
result3 = get_result(V_1,beta_k[2], initial)
plot_normhist(result1, result2, result3)

# %% [markdown]
# ### Discussion 4.1
# The figures show that the mean is approximately zero.
# The resulting distribution of particles is insignificantly influenced by a change in $\beta k$. This is reasonable, since the potential $V_1$ is constant, and therefore does not create a concentration gradient. Random walk in a flat potential corresponds to diffusion with constant diffusion coefficient, as seen in section 2 of the project description. This means that the potential does not change the way the diffusion unfolds. It is also apparent that the mathematical probabilites in 3.2 become $p^+ = p^0 = p^- = \frac {1}{3}$, which further explains why the particle distribution closely resembles a normal distribution.

# %% [markdown]
# ## Programming exercise 4.2:

# %%
@jit(nopython=True)
def V_2(x):
    '''
    Potential in exercise 4.2
    '''
    return x

result1 = get_result(V_2,beta_k[0], initial)
result2 = get_result(V_2,beta_k[1], initial)
result3 = get_result(V_2,beta_k[2], initial)
plot_normhist(result1, result2, result3)

# %% [markdown]
# ### Discussion 4.2
# $V_2 (x) = x$ ***Ta med?***
#
# The means in the figures can be explained by the fact that the potential $V_2$ is odd, which means that the particles tend towards negative values to minimize their potential. Therefore, the particles should be centered around a negative value, as they clearly are. Furthermore, the value of the mean decreases as $\beta k$ increases, which is explained by the fact that the potential becomes increasingly influential to the movement of the particles as the ratio increases. In other words, the thermal energy contributes less and less to the particles' movements.
#
# When $\beta k = 0.01$ the distribution resembles a normal distribution to a great degree. It's resemblance is not quite as clear as for potential $V_1$, but it is still quite clear that the potential does not significantly change the diffusion process.
#
# When $\beta k = 1$ the standard deviation is less and the mean is more negative. The distribution still resembles the normal distribution in the graph, but the values show that the resemblance is not as clear as before. This is because of the stronger influence of the potential compared to when the ratio $\beta k$ was lower.
#
# When $\beta k = 100$ the particle distribution no longer resembles a normal distribution. This is because the thermal energy no longer significantly dictates the diffusion process, and therefore all the particles will diffuse to a highly negative position. In this manner their potential energy is lowered.
#
# ***Alternativ til de tre siste avsnittene:***
#
# We see that for $\beta k=0.01$ the diststribution resembles a normal distribution to a great degree with a mean slightly moved from the center $x=0$. As $\beta k$ increases the the standard deviation decreases which means that the distribution gets more concentrated, and the mean increases in negative direction. For $\beta k=100$ the potential is so strong that all the particles are centered in $x=-200$ which is the lowest possible point after $200$ time steps.

# %% [markdown]
# ## Programming exercise 4.3:

# %%
@jit(nopython=True)
def V_3(x):
    '''
    Potential in exercise 4.3
    '''
    return ((x/20)+np.sin(x/5))

result1 = get_result(V_3,beta_k[0], initial)
result2 = get_result(V_3,beta_k[1], initial)
result3 = get_result(V_3,beta_k[2], initial)
plot_hist(result1, result2, result3)

# %% [markdown]
# ### Discussion task 4.3
# $V_3 (x) = \frac{x}{20} + \sin(x/5)$. ***Ta med?***
#
#
# The potential $V_3$, as illustrated in the next section, is a harmonic potential which means that the potential creates many "pits" with local minimum ***(minima?)*** points. For $\beta k=0.01$ the strength of the potential is too low to affect the particles in any way so the particle distribution looks like a normal distribution caused by only the diffusion process. With $\beta k=100$ all the particles fall down in the nearest "pit" from the center which is around $x=-9$. The potential is so strong that none of the particles can "jump" over a to another "pit" and fall down a to a lower potential. The intermediate ratio, $\beta k=1$, creates a distribution where most of the particles is in the nearest "pit", but some have settled at other positions. If we look closely we can see that there are more particles at $x=20$ than $x=10$ which is becuase there is a local minima at $x=20$.

# %% [markdown]
# ### Additional task for exercise 4.3

# %%
def plot_hist2(result):
    x = np.arange(min(result),max(result),1)
    counts, bins = np.histogram(result)
    plt.hist(bins[:-1], bins, weights=counts/1000)  # scaling down the histogram
    plt.show()

particles = get_result(V_3, beta_k[2], get_result(V_3,beta_k[0], initial))
x = np.arange(min(particles)-10,max(particles),1)
plt.plot(x,V_3(x), color="m", label = r"Potential $V_3$")                  # plots the potential V_3(x)
plt.plot(x,initial[:len(x)], color='k')                          #Trenger en x-akse her!!                        
#plt.axis.set(option='on')       
plt.legend()
plot_hist2(particles)

# %% [markdown]
# ### Observations in additional task
# Here the "pits" of the harmonic potential $V_3$ is illustrated along with the particle distribution.
#
# After $200$ time steps with $\beta k=0.01$ the particles will be distributed as shown in the figure above. When we start a new session with $200$ time steps and $\beta k=100$, each particle will fall down in the nearest "pit". For this case the "pits" seems to be be located around $x=-40$, $x=-9$ and $x=20$.

# %% [markdown]
# ## Programming exercise 4.4:

# %%
@jit(nopython=True)
def V_4(x):
    '''
    Potential in exercise 4.4
    '''
    return x**2

result1 = get_result(V_4,beta_k[0], initial)
result2 = get_result(V_4,beta_k[1], initial)
result3 = get_result(V_4,beta_k[2], initial)
plot_hist(result1, result2, result3)

# %% [markdown]
# ### Discussion 4.4
# $V_4 (x) = x^2$. ***Ta med?***
#
#
# The mean in the figures can be explained by the fact that the potential $V_4$ is even, which means that the particles tend towards $x = 0$ to minimize their potential ***De må ikke gå mot null kun fordi potensialet er jevnt***. Therefore, the particles should be centered around $x = 0$, as we can see in all three plots. The mean stays approximately equal to zero.
#
# When $\beta k = 0.01$ the distribution resembles a normal distribution to some degree. It's resemblance is not quite as clear as for some of the potentials dicussed earlier, but the potential does not significantly change the diffusion process when $\beta k = 0.01$. This is because the thermal energy should be dominant at this ratio, as we have seen earlier.
#
# When $\beta k = 1$ the significance of the potential on the diffusion process is greater than before, which can explain how the particles are distributed. All the particles that were spread in positive and neagtive x-axis are now able to get closer to the point of minimal potential energy, $x = 0$, since the ratio between the thermal and potential energy is higher. It is expected that the particles become less spread out and more centered around the mean as the ratio between thermal and potential energy further increases.
#
# When $\beta k = 100$ it is apparent that our expectation holds. This is because the thermal energy no longer significantly dictates the diffusion process, and therefore all the particles will diffuse to the mean. In this manner their potential energy is lowered.
#
# ***Prøvde å sammensveise det som stod over:***
# Since the potential $V_4$ is even we will see a symmetric particle distribution around the y-axis, and the mean will stay approximately equal to zero. The potential has a global minima at the center so when the ratio $\beta k$ increases all particles will be concentrated at the center.
#
# With $\beta k=0.01$ the particle distribution resembles a normal distribution, which can be explained by the fact that the thermal energy is dominant and the potential does not change the diffusion process. When $\beta k$ increases we see the distribution gets more and more concentrated until we reach the ratio $\beta k=100$ where all he particles are at the minimum***(minima?)*** of the potential. This is in accordance with what we have seen before. With the ratio $\beta k=100$ the potential is fully dominant.
#
#
# ***Can βk alone be used as a ratio to determine whether the thermal energy or potential energy dominates
# the random walk behavior in this potential? Why, or why not?***
#
# If we compare the standard deviations for the potentials $V_4$ and $V_1$ at the same ratio $\beta k=0.01$ we see that the distribution with $V_4$ has a much lower deviation. This is because the shape of the potential influence the particles' movement. This means that the ratio $\beta k$ can not alone be used to determine whether the thermal energy or the potential energy dominates.

# %% [markdown]
# # 5 Random walk in a ratchet potential

# %%
#Constants
h = 1   #step length
T_p = 500 
delta_t = 1
beta_k = 1000
N_x = 90  
N_p = 12*N_x
cycles = 10
jumps = 2*cycles

alpha = 0.8

x_first=-N_x+h          
x_last = N_x          

'''Tror denne er feil
@jit(nopython=True)
def V_sawtooth(x, alpha): 
    
    if not (-(1-alpha)*N_x < x <= alpha*N_x): 
        x = x+N_x    #periodicity of the function
    if alpha != 0:
      if (0 < x <= alpha*N_x):
          return x/(alpha*N_x) 
      else:
          return -1*(x/((1-alpha)*N_x))
    else:
      return np.inf
'''

@jit(nopython=True)
def V_sawtooth(x, alpha):
    '''
    Potential V_1(x) from the task description
    ''' 
    if x <= -(1-alpha)*N_x: 
        x += N_x
    elif  alpha*N_x < x:
        x-= N_x
    if (0 < x <= alpha*N_x):
        return x/(alpha*N_x) 
    else:
        return -1*(x/((1-alpha)*N_x))
   

@jit(nopython=True)  
def V_constant(x, alpha):
    '''
    Potential V_2(x) from the task description
    '''
    c = 1
    return c
  
@jit(nopython=True)
def J(n_plus,n_minus):
    '''
    Returns the normalized particle current
    '''
    return (n_plus-n_minus)/N_p


def J_avg(current_list):
    '''
    Returns the average of a list
    '''
    average = sum(current_list)/len(current_list)
    return average

@jit(nopython=True)
def p_minus_cycle(x_0, V, alpha, beta_k): 
    '''
    Probability of random walk step to the left. 
    Uses periodic boundary conditions
    '''
    value = 0
    if x_0 == x_first:
        value = 1/(1+e**(-beta_k*(V(x_0+1,alpha)-V(x_last, alpha)))+e**(-beta_k*(V(x_0,alpha)-V(x_last,alpha))))
    elif x_0 == x_last:
        value = 1/(1+e**(-beta_k*(V(x_first,alpha)-V(x_0-1,alpha)))+e**(-beta_k*(V(x_0,alpha)-V(x_0-1,alpha))))
    else:
        value = 1/(1+e**(-beta_k*(V(x_0+1,alpha)-V(x_0-1,alpha)))+e**(-beta_k*(V(x_0,alpha)-V(x_0-1,alpha))))
    return value

@jit(nopython=True)
def p_plus_cycle(x_0, V, alpha, beta_k):
    '''
    Probability of random walk step to the right. 
    Uses periodic boundary conditions
    '''
    value = 0
    if x_0 == x_first:
        value = 1/(1+e**(-beta_k*(V(x_last,alpha)-V(x_0+1,alpha)))+e**(-beta_k*(V(x_0,alpha)-V(x_0+1,alpha))))
    elif x_0 == x_last:
        value = 1/(1+e**(-beta_k*(V(x_0-1,alpha)-V(x_first,alpha)))+e**(-beta_k*(V(x_0,alpha)-V(x_first,alpha))))
    else:
        value = 1/(1+e**(-beta_k*(V(x_0-1,alpha)-V(x_0+1,alpha)))+e**(-beta_k*(V(x_0,alpha)-V(x_0+1,alpha))))
    return value

@jit(nopython=True)
def fill_particles():
    '''
    Returns an array of particles evenly distributed along the x-axis
    '''
    particles = np.zeros(N_p,dtype = np.int64)
    number = x_first
    for i in range(1,len(particles)+1):
        particles[i-1] = number
        if i%6 == 0:
            number += 1
    return particles

@jit(nopython=True)
def get_current_per_time_step(V, init, time_steps, alpha, beta_k):
    '''
    Returns an array of the normalized particle current per time step
    '''
    current_list_per_time_step = []
    for step in range(time_steps):
        countPos = 0
        countNeg = 0
        for position in range(len(init)):
            p = np.random.uniform(0,1)
            if p <= p_minus_cycle(init[position],V, alpha, beta_k):
                if init[position] == x_first:
                    init[position] = x_last
                else:
                    init[position] -= 1
                countNeg +=1
            elif p > (1-p_plus_cycle(init[position],V, alpha, beta_k)):
                if init[position] == x_last:
                    init[position] = x_first
                else:
                    init[position] += 1
                countPos +=1
        current_list_per_time_step.append(J(countPos, countNeg))
    return current_list_per_time_step

def get_cycle_averaged_current(particles, V1, V2, T_p, jumps, alpha, beta_k):
    '''
    Returns an array of the cycle-averaged currents for the specified jumps (jumps = 2*cycles)
    '''
    average_currents = []
    for i in range(jumps):
        if i%2 == 0:
            current_list = []
            currents_per_time_step = get_current_per_time_step(V2,particles,T_p, alpha, beta_k)
            current_list = currents_per_time_step
        else:
            currents_per_time_step = get_current_per_time_step(V1,particles,T_p, alpha, beta_k)
            current_list += currents_per_time_step
            average_currents.append(round(J_avg(current_list),15)) #Round the currents to as many digits as possible while the array below is visible in it's entirety on the screen. 
    return average_currents

def plot_potential():
  '''
  Plots the sawtooth potential
  '''
  x = np.linspace(-N_x,N_x,2*N_x)
  y = np.zeros(len(x))
  for i in range(len(x)):
    y[i] = V_sawtooth(x[i],alpha)
  plt.plot(x,y)
  plt.xlabel("$x$", fontsize = 20)
  plt.ylabel("$V(x)$",fontsize = 20)
  plt.title(r"$\alpha = $" + str(alpha),fontsize = 20)
  plt.show()

@jit(nopython=True)
def reset_positioning():
    '''
    Returns an array of particles which are reset to: half of the particles 
    at each of the two x-coordinates which coincide with minima of V_sawtooth. 
    '''
    particles = np.zeros(N_p,dtype = np.int64)
    for i in range(len(particles)):
        if i < (len(particles)/2):
            particles[i] = 0
        else: 
            particles[i] = N_x 
    return particles

# %% [markdown]
# ## 5.1 Programming exercise 5.1

# %%
alpha = 0.8
particles = fill_particles()
plot_potential() 
print(get_cycle_averaged_current(particles,V_sawtooth, V_constant,T_p, jumps,alpha, beta_k))



alpha = 0.2
particles = fill_particles()
plot_potential() 
print(get_cycle_averaged_current(particles,V_sawtooth, V_constant,T_p, jumps,alpha, beta_k))
print(particles[:40])
# Out:
# [-0.027083333333333, -0.014, -0.011666666666667, -0.01425, -0.011666666666667, -0.014416666666667, -0.01475, -0.014, -0.010166666666667, -0.015916666666667]
# [0.024833333333333, 0.013833333333333, 0.013666666666667, 0.015416666666667, 0.015083333333333, 0.014166666666667, 0.012416666666667, 0.01525, 0.013416666666667, 0.013]
# [ 0 90 90 90 90 90  0  0  0 90  0  0 90  0  0 90 90  0  0  0  0 90 90  0
#  90 90 90  0 90 90  0  0 90  0 90 90  0 90 90  0]

# %% [markdown]
# ###Discussion 5.1

# %% [markdown]
# * Why we get non-zero currents:
#
# Since we do not have the symmetric case (where $\alpha = 0.5$) there has to be a non-zero current. As we have seen earlier, if the potential is strong enough the particles will always move towards lower potential. In this simulation $\beta k=1000$, which, based on the results in exercise 4, indeed can be said to be strong enough. In that exercise we clearly saw that the particles moved towards the lowest possible potential when $\beta k=100$, which implies that it is fair to expect that the potential dictates the movement of the particles even more at $\beta k=1000$. As we can see in the illustrations of the potentials, when $\alpha =0.8$ the sawtooth potential is leaning to the right, which means that the bottom is offset to the left. In other words, a particle de-exciting into the sawtooth potential will, on average, travel to the left, since it will move towards the bottom to minimize its potential.
# When $\alpha = 0.2$ we will have the opposite situation, where the potential  leans leftward, resulting in a positive current. We can also see that the absolute values of the current are approximately equal whether $\alpha=0.8$ or $\alpha = 0.2$.

# %% [markdown]
# * Compare $J_{avg}(0)$ with $J_{avg}(n)$ for n > 0:
#
# It is apparent that the averaged current during the first cycle is bigger in absolute value than the other cycle-averaged currents. The fact that the particles seek to minimize their potential energy can be used to give a physical interpretaion of this observation. The particles are the furthest from the positions of lowest potential in the beginning, when they are uniformly distributed. In contrast, all the consecutive cycles have an initial position where all the particles are in either one of the minimas. With this initial distribution the constant potential only distributes the particles isotropic with center at the minimas, but not quite uniform. This is why in the first cycle the potential have more particles to move in to the minima than in the cycles after.

# %% [markdown]
# ## Programming exercise 5.2

# %% [markdown]
# The two x-coordinates which coincide with the minima of $V_1(x)$ must be $x = 0$ and $x = 0 + nN_x$, since it is periodic. The part of $V_1(x)$ which lies within $0 < x \leq \alpha N_x$ is a monotonically increasing function, which means that it's minima is when $x$ is the smallest in the given interval $\Rightarrow$ $x = 0$. The other part of $V_1(x)$ is a monotonically decreasing function, which means that it's minima is at the highest possible $x$ value in the interval $\Rightarrow$ x = 0. However, because of the periodicity of the function, the other minima is at $x = N_x$.

# %%
#Constants
N_p = 40*N_x
alpha = 0.8
jumps=2
beta_k = 1000


@jit(nopython=True)
def reset_positioning():
    '''
    Returns an array of particles which are reset to: half of the particles 
    at each of the two x-coordinates which coincide with minima of V_sawtooth. 
    '''
    particles = np.zeros(N_p,dtype = np.int64)
    for i in range(len(particles)):
        if i < (len(particles)/2):
            particles[i] = 0
        else: 
            particles[i] = N_x 
    return particles
print(reset_positioning())
def avg_current_vs_time(T_p_values):    
    '''
    Returns an array of average currents, which can be used to plot vs T_p
    '''
    average_currents = []
    particles = reset_positioning()
    for T_p in T_p_values:
        average_currents+=get_cycle_averaged_current(particles, V_sawtooth, V_constant, T_p, jumps, alpha, beta_k)
    return np.array(average_currents)


T_p_values = np.linspace(1,500,50)
plt.plot(T_p_values, avg_current_vs_time(T_p_values))
plt.xlabel(r"$T_p$", fontsize=15)
plt.ylabel(r"$J_{\mathrm{avg}}$", fontsize=15)
plt.show()
# Out:
# [ 0  0  0 ... 90 90 90]

# %% [markdown]
# ### Observation and physical interpretation:
#
# From the graph it is apparent that the absolute value of the cycle-averaged current increases $T_p$ increases. This is because when $T_p$ is small the particles don't have "time" to get distributed around the x-axis in the constant potential and therefore the sawtooth potential makes fewer particles move in the negative direction. We observe that the values of the average current are closely related to the values obtained in exercise 5.1 (except from $J_{avg}(0)$), which makes sense, since the starting position of the particles is approximately the same in both cases..

# %% [markdown]
# ## Programming exercise 5.3

# %%
N_p = 12*N_x 
T_p = 500
jumps = 2
beta_k = 1000

def avg_current_vs_alpha(alpha_values, beta_k):       
    '''
    Returns an array of average currents, which can be used to plot vs alpha
    '''
    average_currents = []
    particles = reset_positioning()
    for alpha in alpha_values:
        average_currents+=get_cycle_averaged_current(particles, V_sawtooth, V_constant, T_p, jumps, alpha, beta_k)
    return np.array(average_currents)

alpha_values = np.linspace(0.01,1,50)    #Alpha can't be 0
plt.plot(alpha_values, avg_current_vs_alpha(alpha_values, beta_k))
plt.xlabel(r"$\alpha$", fontsize=15)
plt.ylabel(r"$J_{\mathrm{avg}}$", fontsize=15)
plt.show()

# %% [markdown]
# ### Observation and physical interpretation:
#
# From the graph it is apparent that the average current decreases as $\alpha$ increases. This is since the "peaks" of the potential are moved as $\alpha$ changes. As we have seen earlier, $\alpha < 0.5$ gives positive currents and $\alpha > 0.5$ gives negative currents. This is in accordance with the graph.

# %% [markdown]
# # 6 Analytical solution

# %% [markdown]
# ## Programming exercise 6.1

# %%
T_p = 500
jumps = 2
beta_k = 1000
h = 1   #step length
N_x=90  #Må sette den tilbake til 90 ettersom N_x=10 i forrige opg.
N_p = 12*N_x
x_first=-N_x+h          
x_last = N_x


from scipy import special

def J_avg_an(alpha,T_p):
  return  N_x/(4*T_p) * (special.erfc( alpha*N_x/2 * np.sqrt(3/T_p) ) - special.erfc( (1-alpha)*N_x/2 * np.sqrt(3/T_p)))

@jit(nopython=True)
def reset_positioning():
    '''
    Returns an array of particles which are reset to: half of the particles 
    at each of the two x-coordinates which coincide with minima of V_sawtooth. 
    '''
    particles = np.zeros(N_p,dtype = np.int64)
    for i in range(len(particles)):
        if i < (len(particles)/2):
            particles[i] = 0
        else: 
            particles[i] = N_x 
    return particles


alpha_values = np.linspace(0.01,1,50)   #Alpha can't be zero
plt.plot(alpha_values, avg_current_vs_alpha(alpha_values, beta_k))
plt.plot(alpha_values,J_avg_an(alpha_values,T_p))
plt.xlabel(r"$\alpha$", fontsize=15)
plt.ylabel(r"$J_{\mathrm{avg}}$", fontsize=15)
plt.show()

# %% [markdown]
# ### Comparison and comment on the graphs:
#
# ***What limitations does the analytical solution have compared to the results of the simulation? What is the difference?***

# %% [markdown]
# ## Programming exercise 6.2

# %%
#Constants
h = 1   #step length
N_x = 10   #Det er god overenstemmelse med N_x=90!!
N_p = 3600   #40*N_x fra forrige oppg. (se presisering)
alpha = 0.8
jumps=2
beta_k = 1000
x_first= -N_x+h          
x_last = N_x

'''
@jit(nopython=True)
def V_sawtooth(x, alpha): 
    #V_1(x) from the task-description
    if not (-(1-alpha)*N_x < x <= alpha*N_x): 
        x = x+N_x #periodicity of the function
    if alpha != 0:
      if (0 < x <= alpha*N_x):
          return x/(alpha*N_x) 
      else:
          return -1*(x/((1-alpha)*N_x))
    else:
      return np.inf
'''

def J_avg_an(alpha,T_p):
  return  N_x/(4*T_p) * (special.erfc( (alpha*N_x/2) * np.sqrt(3/T_p) ) - special.erfc( ((1-alpha)*N_x/2) * np.sqrt(3/T_p)))

#Plotter J(T_p) i (80,1500)
T_p_values2 = np.linspace(80,1500,20)
plt.plot(T_p_values2, avg_current_vs_time(T_p_values2))
plt.plot(T_p_values2,J_avg_an(alpha,T_p_values2))
plt.show()
#Legge på aksenavn her også

# %% [markdown]
# ### Comparison and comment on the graphs:

# %% [markdown]
# ## Programming exercise 6.3

# %%
#Plotter J(alpha)
h = 1   #step length
N_x=90  #Må sette den tilbake til 90 ettersom N_x=10 i forrige opg.
x_first=-N_x+h          
x_last = N_x
N_p = 12*N_x
T_p = 500

jumps = 2

beta_and_k = [0.01, 1, 2, 3, 5, 10]

alpha_values = np.linspace(0.01,1,50)    #Alpha can't be zero
for i in range(len(beta_and_k)):
    plt.plot(alpha_values, avg_current_vs_alpha(alpha_values, beta_and_k[i]))
    plt.plot(alpha_values, J_avg_an(alpha_values,T_p))
    plt.show()
#Legge på aksenavn her også!

# %% [markdown]
# ## Exercise 6.4

# %% [markdown]
# In section 6 in the task description, the following is stated:
#
#
# > "*When the particles find themselves in the sawtooth-shaped potential $V1(x)$, they will relax towards the potential minima. Hence, as the particles are excited to the second energy level defined by $V_2(x)$, they start out localized at positions $x_n = nN_x$, $n ∈ Z$."*
#
#
# In other words, it is assumed that the particles in $V_1$ will move with respect to the potential only, regardless of the thermal energy. This situation corresponds to $\beta k >> 1$, which is why the numerical values fit the theoretical better for large values of $\beta k$.
#
# *   List item
# *   List item
